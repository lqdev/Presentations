// %%
#r "nuget:Microsoft.Data.Analysis,0.2.0"
// Out:
// Installed package Microsoft.Data.Analysis version 0.2.0
// input.fsx (1,17)-(1,21) typecheck error The value, constructor, namespace or type 'Data' is not defined.

// %%
using Microsoft.Data.Analysis;

// %%
PrimitiveDataFrameColumn<DateTime> dateTimes = new PrimitiveDataFrameColumn<DateTime>("DateTimes"); // Default length is 0.
PrimitiveDataFrameColumn<int> ints = new PrimitiveDataFrameColumn<int>("Ints", 3); // Makes a column of length 3. Filled with nulls initially
StringDataFrameColumn strings = new StringDataFrameColumn("Strings", 3); // Makes a column of length 3. Filled with nulls initially

// %%
// Append 3 values to dateTimes
dateTimes.Append(DateTime.Parse("2019/01/01"));
dateTimes.Append(DateTime.Parse("2019/01/01"));
dateTimes.Append(DateTime.Parse("2019/01/02"));

// %%
DataFrame df = new DataFrame(dateTimes, ints, strings ); // This will throw if the columns are of different lengths

// %%
df
// Out:
// <table><thead><tr><th>Columns</th><th>Rows</th></tr></thead><tbody><tr><td>[ [ 2019-01-01 00:00:00Z, 2019-01-01 00:00:00Z, 2019-01-02 00:00:00Z ], [ &lt;null&gt;, &lt;null&gt;, &lt;null&gt; ], [ &lt;null&gt;, &lt;null&gt;, &lt;null&gt; ] ]</td><td>[ [ 2019-01-01 00:00:00Z, &lt;null&gt;, &lt;null&gt; ], [ 2019-01-01 00:00:00Z, &lt;null&gt;, &lt;null&gt; ], [ 2019-01-02 00:00:00Z, &lt;null&gt;, &lt;null&gt; ] ]</td></tr></tbody></table>

// %%
using Microsoft.AspNetCore.Html;
Formatter<DataFrame>.Register((df, writer) =>
{
    var headers = new List<IHtmlContent>();
    headers.Add(th(i("index")));
    headers.AddRange(df.Columns.Select(c => (IHtmlContent) th(c.Name)));
    var rows = new List<List<IHtmlContent>>();
    var take = 20;
    for (var i = 0; i < Math.Min(take, df.Rows.Count); i++)
    {
        var cells = new List<IHtmlContent>();
        cells.Add(td(i));
        foreach (var obj in df.Rows[i])
        {
            cells.Add(td(obj));
        }
        rows.Add(cells);
    }
    
    var t = table(
        thead(
            headers),
        tbody(
            rows.Select(
                r => tr(r))));
    
    writer.Write(t);
}, "text/html");

// %%
df
// Out:
// <table><thead><th><i>index</i></th><th>DateTimes</th><th>Ints</th><th>Strings</th></thead><tbody><tr><td>0</td><td>2019-01-01 00:00:00Z</td><td>&lt;null&gt;</td><td>&lt;null&gt;</td></tr><tr><td>1</td><td>2019-01-01 00:00:00Z</td><td>&lt;null&gt;</td><td>&lt;null&gt;</td></tr><tr><td>2</td><td>2019-01-02 00:00:00Z</td><td>&lt;null&gt;</td><td>&lt;null&gt;</td></tr></tbody></table>

// %%
// To change a value directly through df
df[0, 1] = 10; // 0 is the rowIndex, and 1 is the columnIndex. This sets the 0th value in the Ints columns to 10
df
// Out:
// <table><thead><th><i>index</i></th><th>DateTimes</th><th>Ints</th><th>Strings</th></thead><tbody><tr><td>0</td><td>2019-01-01 00:00:00Z</td><td>10</td><td>&lt;null&gt;</td></tr><tr><td>1</td><td>2019-01-01 00:00:00Z</td><td>&lt;null&gt;</td><td>&lt;null&gt;</td></tr><tr><td>2</td><td>2019-01-02 00:00:00Z</td><td>&lt;null&gt;</td><td>&lt;null&gt;</td></tr></tbody></table>

// %%
// Modify ints and strings columns by indexing
ints[1] = 100;
strings[1] = "Foo!";
df
// Out:
// <table><thead><th><i>index</i></th><th>DateTimes</th><th>Ints</th><th>Strings</th></thead><tbody><tr><td>0</td><td>2019-01-01 00:00:00Z</td><td>10</td><td>&lt;null&gt;</td></tr><tr><td>1</td><td>2019-01-01 00:00:00Z</td><td>100</td><td>Foo!</td></tr><tr><td>2</td><td>2019-01-02 00:00:00Z</td><td>&lt;null&gt;</td><td>&lt;null&gt;</td></tr></tbody></table>

// %%
// Indexing can throw when types don't match.
// ints[1] = "this will throw because I am a string";  
// Info can be used to figure out the type of data in a column. 
df.Info()
// Out:
// <table><thead><th><i>index</i></th><th>Info</th><th>DateTimes</th><th>Ints</th><th>Strings</th></thead><tbody><tr><td>0</td><td>DataType</td><td>System.DateTime</td><td>System.Int32</td><td>System.String</td></tr><tr><td>1</td><td>Length (excluding null values)</td><td>3</td><td>2</td><td>3</td></tr></tbody></table>

// %%
// Add 5 to ints through the DataFrame
df["Ints"].Add(5, inPlace: true);
df
// Out:
// <table><thead><th><i>index</i></th><th>DateTimes</th><th>Ints</th><th>Strings</th></thead><tbody><tr><td>0</td><td>2019-01-01 00:00:00Z</td><td>15</td><td>&lt;null&gt;</td></tr><tr><td>1</td><td>2019-01-01 00:00:00Z</td><td>105</td><td>Foo!</td></tr><tr><td>2</td><td>2019-01-02 00:00:00Z</td><td>&lt;null&gt;</td><td>&lt;null&gt;</td></tr></tbody></table>

// %%
// We can also use binary operators. Binary operators produce a copy, so assign it back to our Ints column 
df["Ints"] = (ints / 5) * 100;
df
// Out:
// <table><thead><th><i>index</i></th><th>DateTimes</th><th>Ints</th><th>Strings</th></thead><tbody><tr><td>0</td><td>2019-01-01 00:00:00Z</td><td>300</td><td>&lt;null&gt;</td></tr><tr><td>1</td><td>2019-01-01 00:00:00Z</td><td>2100</td><td>Foo!</td></tr><tr><td>2</td><td>2019-01-02 00:00:00Z</td><td>&lt;null&gt;</td><td>&lt;null&gt;</td></tr></tbody></table>

// %%
// Fill nulls in our columns, if any. Ints[2], Strings[0] and Strings[1] are null
df["Ints"].FillNulls(-1, inPlace: true);
df["Strings"].FillNulls("Bar", inPlace: true);
df
// Out:
// <table><thead><th><i>index</i></th><th>DateTimes</th><th>Ints</th><th>Strings</th></thead><tbody><tr><td>0</td><td>2019-01-01 00:00:00Z</td><td>300</td><td>Bar</td></tr><tr><td>1</td><td>2019-01-01 00:00:00Z</td><td>2100</td><td>Foo!</td></tr><tr><td>2</td><td>2019-01-02 00:00:00Z</td><td>-1</td><td>Bar</td></tr></tbody></table>

// %%
// To inspect the first row
DataFrameRow row0 = df.Rows[0];
row0
// Out:
// <table><thead><tr><th><i>index</i></th><th>Date</th><th>Day</th><th>DayOfWeek</th><th>DayOfYear</th><th>Hour</th><th>Kind</th><th>Millisecond</th><th>Minute</th><th>Month</th><th>Second</th><th>Ticks</th><th>TimeOfDay</th><th>Year</th></tr></thead><tbody><tr><td>0</td><td>2019-01-01 00:00:00Z</td><td>1</td><td>{ System.DayOfWeek: value__: 2 }</td><td>1</td><td>0</td><td>{ System.DateTimeKind: value__: 0 }</td><td>0</td><td>0</td><td>1</td><td>0</td><td>636818976000000000</td><td>{ System.TimeSpan: Ticks: 0, Days: 0, Hours: 0, Milliseconds: 0, Minutes: 0, Seconds: 0, TotalDays: 0, TotalHours: 0, TotalMilliseconds: 0, TotalMinutes: 0, TotalSeconds: 0 }</td><td>2019</td></tr><tr><td>1</td><td>300</td></tr><tr><td>2</td><td>Bar</td></tr></tbody></table>

// %%
using Microsoft.AspNetCore.Html;
Formatter<DataFrameRow>.Register((dataFrameRow, writer) =>
{
    var cells = new List<IHtmlContent>();
    cells.Add(td(i));
    foreach (var obj in dataFrameRow)
    {
        cells.Add(td(obj));
    }
    
    var t = table(
        tbody(
            cells));
    
    writer.Write(t);
}, "text/html");

// %%
row0
// Out:
// <table><tbody><td><i></i></td><td>2019-01-01 00:00:00Z</td><td>300</td><td>Bar</td></tbody></table>

// %%
// Filter rows based on equality
PrimitiveDataFrameColumn<bool> boolFilter = df["Strings"].ElementwiseEquals("Bar");
boolFilter
// Out:
// <table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td>True</td></tr><tr><td>1</td><td>False</td></tr><tr><td>2</td><td>True</td></tr></tbody></table>

// %%
DataFrame filtered = df.Filter(boolFilter);
filtered
// Out:
// <table><thead><th><i>index</i></th><th>DateTimes</th><th>Ints</th><th>Strings</th></thead><tbody><tr><td>0</td><td>2019-01-01 00:00:00Z</td><td>300</td><td>Bar</td></tr><tr><td>1</td><td>2019-01-02 00:00:00Z</td><td>-1</td><td>Bar</td></tr></tbody></table>

// %%
// Sort our dataframe using the Ints column
DataFrame sorted = df.Sort("Ints");
sorted
// Out:
// <table><thead><th><i>index</i></th><th>DateTimes</th><th>Ints</th><th>Strings</th></thead><tbody><tr><td>0</td><td>2019-01-02 00:00:00Z</td><td>-1</td><td>Bar</td></tr><tr><td>1</td><td>2019-01-01 00:00:00Z</td><td>300</td><td>Bar</td></tr><tr><td>2</td><td>2019-01-01 00:00:00Z</td><td>2100</td><td>Foo!</td></tr></tbody></table>

// %%
// GroupBy 
GroupBy groupBy = df.GroupBy("DateTimes");
// Count of values in each group
DataFrame groupCounts = groupBy.Count();
groupCounts
// Out:
// <table><thead><th><i>index</i></th><th>DateTimes</th><th>Ints</th><th>Strings</th></thead><tbody><tr><td>0</td><td>2019-01-01 00:00:00Z</td><td>2</td><td>2</td></tr><tr><td>1</td><td>2019-01-02 00:00:00Z</td><td>1</td><td>1</td></tr></tbody></table>

// %%
// Alternatively find the sum of the values in each group in Ints
DataFrame intsGroupSum = groupBy.Sum("Ints");
intsGroupSum
// Out:
// <table><thead><th><i>index</i></th><th>DateTimes</th><th>Ints</th></thead><tbody><tr><td>0</td><td>2019-01-01 00:00:00Z</td><td>2400</td></tr><tr><td>1</td><td>2019-01-02 00:00:00Z</td><td>-1</td></tr></tbody></table>

// %%
using XPlot.Plotly;
using System.Linq;

// %%
#r "nuget:MathNet.Numerics,4.9.0"
// Out:
// Installed package Microsoft.Data.Analysis version 0.2.0
// Installed package MathNet.Numerics version 4.9.0

// %%
using MathNet.Numerics.Distributions;
double mean = 0;
double stdDev = 0.1;

MathNet.Numerics.Distributions.Normal normalDist = new Normal(mean, stdDev);

// %%
PrimitiveDataFrameColumn<double> doubles = new PrimitiveDataFrameColumn<double>("Normal Distribution", normalDist.Samples().Take(1000));
display(Chart.Plot(
    new Graph.Histogram()
    {
        x = doubles,
        nbinsx = 30
    }
));
// Out:
// <div id="2b01a9e3-b049-4d26-b56d-ff4b22cddc7e" style="width: 900px; height: 500px;"></div>
// <script type="text/javascript">
//
// var renderPlotly = function() {
//     var xplotRequire = requirejs.config({context:'xplot-3.0.1',paths:{plotly:'https://cdn.plot.ly/plotly-1.49.2.min'}});
//     xplotRequire(['plotly'], function(Plotly) {
//
//             var data = [{"type":"histogram","x":[0.13269724625146087,-0.0015476636158474413,0.0021922253201535724,0.08194272156778204,0.05004772416197295,0.15822264748221426,0.06106906419184473,-0.011651160800695328,0.04974828319674804,0.056593628038163125,0.04382306013837965,0.08589948750668822,0.030304604648530964,0.09815347804231521,-0.08516835860806224,-0.08662804286372622,0.0952085168444918,-0.006556037579579001,0.09591376341178058,0.12347165843743307,-0.042715222612163144,-0.08000465899485586,-0.09632595418690783,-0.01830231430933645,0.03731421341496662,-0.1021583935978901,-0.2298502366466987,-0.15885338900001456,0.09005797242279118,-0.2362777513942918,-0.07366986285696593,0.1513997559639707,-0.06136718011837248,-0.04410332946934356,0.10422064448466045,-0.01802659860173619,-0.12045352379124073,0.0009171660321984538,-0.041387098359809624,0.06132105414830402,-0.10555141597475529,0.08108715248585625,0.1281785630246708,0.28595079566497356,0.0778080269454113,0.06585562454467299,0.051854357535778176,0.06778021060441992,0.06986581074424317,0.13695158795496115,-0.048568840863936626,0.004686693762777263,-0.057874475123820594,-0.21072232095542587,0.014583654187429624,0.05579692628384965,0.0873013554369485,0.07876873825938102,-0.03142668662457288,0.041584674505994075,-0.00745353073784348,-0.0178122656055106,0.08050953038048593,-0.0733939900841596,-0.03762927053887396,-0.06257377981347904,0.09124136355073285,0.01853268809239236,0.3034159947163915,0.03955606907496645,-0.06893747985976016,-0.04929953474549886,0.04530438804974819,0.07175823464292973,-0.11227610067984949,-0.1262806515311452,0.030189526488517263,-0.09321177794709402,-0.07135569110284508,-0.15924375420385495,0.039210891398301896,0.16571722293694358,0.06970892495967194,-0.03412328066387468,-0.11586398618147815,-0.08612090334320162,-0.03433661658214975,0.21883623890244028,-0.08079528104904435,0.07531101739474048,0.04575825849765366,0.0003471985626488596,0.29524076056923815,0.004470102619871131,0.11566766743526179,-0.01611608903058941,-0.07572708158684195,0.06139137714908147,-0.06114198141921487,0.13486061638235597,-0.03393440406560191,0.00424650337108701,-0.2202048709010024,-0.10738258134253964,-0.027434703570641462,-0.056271844498769985,-0.0027389942626197717,-0.04118425306667847,-0.0015686308408510913,-0.05682425121474604,-0.05378310423531968,-0.13495284241003078,-0.14756349162674287,0.0472206255062248,-0.0336968202121659,-0.2307094529067778,-0.04934116035613836,0.06514980170735701,0.042822704692031116,-0.11315845656515973,-0.0488803565662592,0.05995671881983407,0.032491728762792785,-0.0473629532446788,-0.1567801358540911,0.07600194218926833,0.010576870361155757,-0.09825476815987363,0.03566154658906278,-0.08007766131194446,-0.18276433227451563,0.033863708771626776,0.05729926649355371,0.06469261278954806,-0.02443493959516935,-0.005885222803129395,-0.05527275831608012,-0.04983024726692659,-0.009235193717404708,0.017044464303869074,-0.07512431769471878,-0.03287310624189431,-0.09174998653958516,-0.08930371573244933,0.03285953721738447,0.008722206293930708,0.1358349734716284,-0.09325998211341602,-0.012084583181059746,0.011512262722958872,-0.18795742885936073,0.07409010400956015,0.055890854133846174,-0.09350816786427672,0.13385690770118908,0.006145532946440518,0.033582824264874044,0.05562207009743691,-0.002426560914622099,-0.1813011334079886,0.01499386716770568,-0.09920072185262022,-0.012192473468931524,0.02583124472279673,0.19922816069694593,-0.13438272229715556,0.12107813472156143,-0.040286089529857405,0.08686370167123707,-0.01855668858181928,0.050883709049459803,-0.02565439904991166,0.16716644491516922,-0.05306856714008873,-0.09686416413103095,-0.03644620218908152,0.034551798463258517,-0.003561747653482893,-0.06188550268924621,-0.06127524488243046,0.07725104476801668,0.1898557292525856,-0.04607101737772372,-0.23197731029758836,-0.022754125477059853,0.12294807709135949,0.041174221970774916,-0.05340740032460585,0.1290257366531913,0.23374207442282918,-0.06726964197913397,0.1539 ...
